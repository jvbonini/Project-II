# %% [markdown]
# # <center>Games Stats</center>

# %%
#import
import plotly
from plotly import __version__
print (__version__)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# 3.10.0

# %%
#Jupyter setup
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <br>
#
# To save the chart to Plotly Cloud or Plotly Enterprise, use `plotly.plotly.iplot`.
#
# Use py.plot() to return the unique url and optionally open the url.
#
# Use py.iplot() when working in a Jupyter Notebook to display the plot in the notebook.
#
# <br>

# %%
import pandas as pd

# %%
pubg = pd.read_csv('PUBG.csv')
#pubg.head(10)
df_pubg = pubg.apply(pd.to_numeric, errors='ignore')
df_new_pubg = df_pubg.head(10)

# %%
df_new_pubg.head(10)
# Out:
#         game_name  Navy_clear_attempts  Navy_draw_controls  \
# 0        Virginia                   19                  19
# 1  Saint Joseph's                   19                  17
# 2          Towson                   13                  26
# 3       Villanova                   21                   7
# 4         Florida                   18                  16
# 5  Boston College                   24                  21
# 6           Brown                   21                  19
# 7         Colgate                   23                  11
# 8        Bucknell                   23                  15
# 9          Lehigh                   22                  16
#
#    Navy_failed_clears  Navy_fouls  Navy_free_positions  Navy_goals  \
# 0                   2          10                    0          20
# 1                   1          16                    0          21
# 2                   0          14                    0          20
# ...

# %%
df_bar_pubg = df_pubg.head(30)

# %%
df_bar_pubg
# Out:
#             game_name  Navy_clear_attempts  Navy_draw_controls  \
# 0            Virginia                   19                  19
# 1      Saint Joseph's                   19                  17
# 2              Towson                   13                  26
# 3           Villanova                   21                   7
# 4             Florida                   18                  16
# 5      Boston College                   24                  21
# 6               Brown                   21                  19
# 7             Colgate                   23                  11
# 8            Bucknell                   23                  15
# 9              Lehigh                   22                  16
# 10         Holy Cross                   17                  16
# 11             Loyola                   20                  16
# 12         Georgetown                   17                  21
# 13    Army West Point                   16                  20
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_clear_attempts'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_clear_attempts'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Attempts',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="bc837946-efad-4231-9f2b-e3ce31b0b293" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bc837946-efad-4231-9f2b-e3ce31b0b293")) {
#                     Plotly.newPlot(
#                         'bc837946-efad-4231-9f2b-e3ce31b0b293',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_draw_controls'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_draw_controls'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Draw controls',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="443fede7-828c-41c7-a9d5-3fc9315b2613" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("443fede7-828c-41c7-a9d5-3fc9315b2613")) {
#                     Plotly.newPlot(
#                         '443fede7-828c-41c7-a9d5-3fc9315b2613',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_failed_clears'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_failed_clears'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Failed_clears',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="8d5f8d15-457c-4b56-91c9-6fcdbd1e89fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8d5f8d15-457c-4b56-91c9-6fcdbd1e89fc")) {
#                     Plotly.newPlot(
#                         '8d5f8d15-457c-4b56-91c9-6fcdbd1e89fc',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_fouls'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_fouls'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Fouls',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="85a1bba1-6f75-42d3-adf0-e19a231320f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("85a1bba1-6f75-42d3-adf0-e19a231320f0")) {
#                     Plotly.newPlot(
#                         '85a1bba1-6f75-42d3-adf0-e19a231320f0',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_free_positions'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_free_positions'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Free positions',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="783678fe-ab31-454f-ba4e-7ac16d6a43c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("783678fe-ab31-454f-ba4e-7ac16d6a43c8")) {
#                     Plotly.newPlot(
#                         '783678fe-ab31-454f-ba4e-7ac16d6a43c8',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_goals'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_goals'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Goals',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="c3e05356-19c4-4527-b119-d520c16643f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c3e05356-19c4-4527-b119-d520c16643f2")) {
#                     Plotly.newPlot(
#                         'c3e05356-19c4-4527-b119-d520c16643f2',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_ground_ball_pickups'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_ground_ball_pickups'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Ground_ball pickups',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="b9c51394-337c-427d-b4a1-bf958155f162" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b9c51394-337c-427d-b4a1-bf958155f162")) {
#                     Plotly.newPlot(
#                         'b9c51394-337c-427d-b4a1-bf958155f162',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_possessions'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_possessions'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Possessions',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="d85ec162-0896-46da-a45a-42ad38025624" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d85ec162-0896-46da-a45a-42ad38025624")) {
#                     Plotly.newPlot(
#                         'd85ec162-0896-46da-a45a-42ad38025624',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_shots'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_shots'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Shots',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="b602b59d-bc5b-47b8-bbad-f2c0808ac51a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b602b59d-bc5b-47b8-bbad-f2c0808ac51a")) {
#                     Plotly.newPlot(
#                         'b602b59d-bc5b-47b8-bbad-f2c0808ac51a',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_successful_clears'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_successful_clears'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Successful clears',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="b10dbf9b-6bb4-48f0-882a-45b2a6a598d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b10dbf9b-6bb4-48f0-882a-45b2a6a598d0")) {
#                     Plotly.newPlot(
#                         'b10dbf9b-6bb4-48f0-882a-45b2a6a598d0',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_timeouts'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_timeouts'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Timeouts',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="d10fb64e-6769-45a9-9f5d-a41e069033df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d10fb64e-6769-45a9-9f5d-a41e069033df")) {
#                     Plotly.newPlot(
#                         'd10fb64e-6769-45a9-9f5d-a41e069033df',
# ...

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['Navy_turnovers'],
        name= 'Navy')

trace2 = go.Bar( 
        x = df_bar_pubg['game_name'],
        y = df_bar_pubg['opponent_turnovers'],
        name= 'Opponent')

# %%
data = [trace1, trace2]
layout = go.Layout(title='Turnovers',barmode='group')
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>
#
#
#             <div id="21a96168-bbe0-4375-b5df-976c3dd07eb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("21a96168-bbe0-4375-b5df-976c3dd07eb2")) {
#                     Plotly.newPlot(
#                         '21a96168-bbe0-4375-b5df-976c3dd07eb2',
# ...
